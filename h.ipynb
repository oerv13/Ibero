# %% [markdown]
# <a href="https://colab.research.google.com/github/oerv13/Ibero/blob/main/h.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-cloud-storage

# %%
from google.colab import auth
# Resto de Codigo
auth.authenticate_user()

# %%
from google.cloud import storage
import os
from google.colab import auth

# Configurar el cliente
client = storage.Client()

# Acceder al bucket y archivo
bucket = client.get_bucket('bigbata_buckets')
blop = bucket.blob('summer.csv')
blop.download_to_filename('summer.csv')

# Cargar Archivo descargado en un DataFrame de Pandas
import pandas as pd
df = pd.read_csv('summer.csv')
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
# Resumen estadistico de los datos
df.describe()

# Filtrado de datos
datos_filtrados = df[df['Country'] == 'COL']
print(datos_filtrados.head())
# Out:
#        Year         City     Sport Discipline                     Athlete  \
# 13101  1972       Munich    Boxing     Boxing             ROJAS, Clemente
# 13105  1972       Munich    Boxing     Boxing              PEREZ, Alfonso
# 13735  1972       Munich  Shooting   Shooting         BELLINGRODT, Helmut
# 17882  1984  Los Angeles  Shooting   Shooting         BELLINGRODT, Helmut
# 18524  1988        Seoul    Boxing     Boxing  JULIO ROCHA, Jorge Eliecer
#
#       Country Gender                             Event   Medal
# 13101     COL    Men         54 - 57KG (Featherweight)  Bronze
# 13105     COL    Men           57 - 60KG (Lightweight)  Bronze
# 13735     COL    Men  50M Running Target (30+30 Shots)  Silver
# 17882     COL    Men  50M Running Target (30+30 Shots)  Silver
# 18524     COL    Men          51 - 54KG (Bantamweight)  Bronze

# %%
# Graficos
import matplotlib.pyplot as plt
df['Country'].hist(bins=50)
plt.show()
