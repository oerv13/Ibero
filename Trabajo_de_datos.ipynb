# %% [markdown]
# <a href="https://colab.research.google.com/github/oerv13/Ibero/blob/main/Trabajo_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46f92775-f534-4ed4-98c0-3f449d806d13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46f92775-f534-4ed4-98c0-3f449d806d13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
url = 'deportistas_participantes_en_cada_competicion_de_juegos_olimpicos_de_verano.csv'
df = pd.read_csv(url)
df
# Out:
#          Año;"Periodo";"Parámetro";"Nota: Berlín 1916  \
# 0                   2024;"Año";"Amberes 1920";"2.626"
# 1                 2024;"Año";"Ámsterdam 1928";"2.883"
# 2                      2024;"Año";"Atenas 1896";"241"
# 3                   2024;"Año";"Atenas 2004";"10.625"
# 4                  2024;"Año";"Atlanta 1996";"10.318"
# 5                 2024;"Año";"Barcelona 1992";"9.356"
# 6                        2024;"Año";"Berlín 1916";"0"
# 7                    2024;"Año";"Berlín 1936";"3.963"
# 8                 2024;"Año";"Estocolmo 1912";"2.587"
# 9                  2024;"Año";"Helsinki 1952";"4.955"
# 10                  2024;"Año";"Londres 1908";"2.008"
# 11                      2024;"Año";"Londres 1944";"0"
# 12                  2024;"Año";"Londres 1948";"4.104"
# 13                 2024;"Año";"Londres 2012";"10.500"
# 14              2024;"Año";"Los Ángeles 1932";"1.332"
# 15              2024;"Año";"Los Ángeles 1984";"6.829"
# ...

# %%
url = 'deportistas_participantes_en_cada_competicion_de_juegos_olimpicos_de_verano.csv'
df = pd.read_csv(url, encoding= 'latin-1', sep = ';')
df
# Out:
#                                             ï»¿"AÃ±o" Periodo  \
# 0                                                2024    AÃ±o
# 1                                                2024    AÃ±o
# 2                                                2024    AÃ±o
# 3                                                2024    AÃ±o
# 4                                                2024    AÃ±o
# 5                                                2024    AÃ±o
# 6                                                2024    AÃ±o
# 7                                                2024    AÃ±o
# 8                                                2024    AÃ±o
# 9                                                2024    AÃ±o
# 10                                               2024    AÃ±o
# 11                                               2024    AÃ±o
# 12                                               2024    AÃ±o
# 13                                               2024    AÃ±o
# ...

# %%
# Atributos de exploración de los df
df.shape
# Out:
# (47, 4)

# %%
df.columns
# Out:
# Index(['ï»¿"AÃ±o"', 'Periodo', 'ParÃ¡metro',
#        'Nota: BerlÃ­n 1916, Tokio 1940 y Londres 1944 se suspendieron por las guerras mundiales'],
#       dtype='object')

# %%
# Modifiquemos los nombres de las variables
name = ['Year','Period','Parameter','Players']

df.columns = name
df.columns
# Out:
# Index(['Year', 'Period', 'Parameter', 'Players'], dtype='object')

# %%
# Métodos generalesde exploración

# df.head(3)
# df.tail(n = 10)
df.sample(n = 3)
# Out:
#                                                  Year Period    Parameter  \
# 45  Titulo:"Deportistas participantes en cada comp...    NaN          NaN
# 35  MÃ©trica:"Nota: BerlÃ­n 1916, Tokio 1940 y Lon...    NaN          NaN
# 20                                               2024   AÃ±o  Munich 1972
#
#     Players
# 45      NaN
# 35      NaN
# 20    7.134

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       43 non-null     object
#  1   Period     33 non-null     object
#  2   Parameter  33 non-null     object
#  3   Players    33 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.6+ KB

# %%
df.isna().sum()
# Out:
# Year          4
# Period       14
# Parameter    14
# Players      14
# dtype: int64

# %%
## Limpeza de datos

df.replace('Ã±','nn',regex = True, inplace= True)
df.replace('Ã','i',regex = True, inplace= True)
df.replace('i','A',regex = True, inplace= True)
df.replace('i©','e',regex = True, inplace= True)
df.replace('iº','u',regex = True, inplace= True)
#df.head()
df.sample(5)
# Out:
#                           Year Period         Parameter  Players
# 21                        2024   Anno       Pari­s 1900  997.000
# 1                         2024   Anno    Amsterdam 1928    2.883
# 40  EscalaFactorPotencia10:"0"    NaN               NaN      NaN
# 41    SonDatosNumericos:"True"    NaN               NaN      NaN
# 15                        2024   Anno  Los Angeles 1984    6.829
